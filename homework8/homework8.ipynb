# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data= pd.read_csv('/Users/alliefisher/python_decal_sp26/course_assignments/course_assignments/homework8/state_data.csv')
print(data)
# Out:
#    state   latitude   longitude                  name
# 0     AK  63.588753 -154.493062                Alaska
# 1     AL  32.318231  -86.902298               Alabama
# 2     AR  35.201050  -91.831833              Arkansas
# 3     AZ  34.048928 -111.093731               Arizona
# 4     CA  36.778261 -119.417932            California
# 5     CO  39.550051 -105.782067              Colorado
# 6     CT  41.603221  -73.087749           Connecticut
# 7     DC  38.905985  -77.033418  District of Columbia
# 8     DE  38.910832  -75.527670              Delaware
# 9     FL  27.664827  -81.515754               Florida
# 10    GA  32.157435  -82.907123               Georgia
# 11    HI  19.898682 -155.665857                Hawaii
# 12    IA  41.878003  -93.097702                  Iowa
# 13    ID  44.068202 -114.742041                 Idaho
# 14    IL  40.633125  -89.398528              Illinois
# 15    IN  40.551217  -85.602364               Indiana
# ...

# %%
np.shape(data) # 52 rows and 4 columns!
# Out:
# (52, 4)

# %%
print(data.head())
print(data.tail())
# Out:
#   state   latitude   longitude        name
# 0    AK  63.588753 -154.493062      Alaska
# 1    AL  32.318231  -86.902298     Alabama
# 2    AR  35.201050  -91.831833    Arkansas
# 3    AZ  34.048928 -111.093731     Arizona
# 4    CA  36.778261 -119.417932  California
#    state   latitude   longitude           name
# 47    VT  44.558803  -72.577841        Vermont
# 48    WA  47.751074 -120.740139     Washington
# 49    WI  43.784440  -88.787868      Wisconsin
# 50    WV  38.597626  -80.454903  West Virginia
# 51    WY  43.075968 -107.290284        Wyoming

# %%
# The first column represents a US state's abbreviation, the second and third column represent random lattitude and longitude points within each state, and the last column lists the name of the state.
# The first state in the data set is Alaksa.
# The last state is Wyoming.
# There are a total of 52 entries, accomodating for python's indexing starting at 0.
# There are more than 50 states listed because the dataframe includes Washington D.C. as well as Puerto Rico.

# %%
print(data['latitude'].median()) # Latitude median is 39.4355155
print(data['longitude'].median()) # Longitude median is -89.093198
# Out:
# 39.4355155
# -89.093198
