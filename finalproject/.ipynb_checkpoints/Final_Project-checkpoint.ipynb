# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy as sp

# %%
data = pd.read_csv("/Users/alliefisher/python_decal_sp26/pythonallie/finalproject/AF_MFU_4l_first_Co_exchange.xy")

# %%
print(data)
# Out:
#       2.00000 4776.000
# 0     2.01947 4694.000
# 1     2.03893 4587.000
# 2     2.05840 4537.000
# 3     2.07787 4279.000
# 4     2.09734 4317.000
# ...                ...
# 1947  39.92172 495.000
# 1948  39.94118 530.000
# 1949  39.96065 462.000
# 1950  39.98012 477.000
# 1951  39.99958 467.000
#
# [1952 rows x 1 columns]
